# %%
#!pip install pyarrow
# Out:
# Collecting pyarrow
#   Downloading pyarrow-6.0.0-cp37-cp37m-win_amd64.whl (15.4 MB)
# Requirement already satisfied: numpy>=1.16.6 in c:\users\rauln\anaconda3\envs\ti\lib\site-packages (from pyarrow) (1.20.3)
# Installing collected packages: pyarrow
# Successfully installed pyarrow-6.0.0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
import pyarrow

# %%
# path = "/content/drive/My Drive/dataEngProject/kym_vision.json"
# Out:
#   File "C:\Users\rauln\AppData\Local\Temp/ipykernel_7476/3082006881.py", line 2
#     pip install pyarrow
#               ^
# SyntaxError: invalid syntax

# %%
#from google.colab import drive
#drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_json("kym_vision.json", orient="index")

# %%
df["url"] = df.index
df = df.reset_index()
df = df.drop(columns=["index"])
df.head()
# Out:
#                                     labelAnnotations  \
# 0  [{'mid': '/m/01yrx', 'description': 'Cat', 'sc...
# 1  [{'mid': '/m/0dzct', 'description': 'Face', 's...
# 2  [{'mid': '/m/068jd', 'description': 'Photograp...
# 3  [{'mid': '/m/09j2d', 'description': 'Clothing'...
# 4  [{'mid': '/m/04hgtk', 'description': 'Head', '...
#
#                                 safeSearchAnnotation  \
# 0  {'adult': 'VERY_UNLIKELY', 'spoof': 'VERY_LIKE...
# 1  {'adult': 'UNLIKELY', 'spoof': 'LIKELY', 'medi...
# 2  {'adult': 'UNLIKELY', 'spoof': 'VERY_LIKELY', ...
# 3  {'adult': 'VERY_UNLIKELY', 'spoof': 'VERY_LIKE...
# 4  {'adult': 'VERY_UNLIKELY', 'spoof': 'VERY_LIKE...
#
#                                         webDetection error  \
# 0  {'webEntities': [{'entityId': '/m/04wpw', 'sco...   NaN
# 1  {'webEntities': [{'entityId': '/m/03bzkh4', 's...   NaN
# 2  {'webEntities': [{'entityId': '/m/09dzg', 'sco...   NaN
# 3  {'webEntities': [{'entityId': '/m/09kqc', 'sco...   NaN
# 4  {'webEntities': [{'entityId': '/m/06ng23', 'sc...   NaN
#
#                                                  url
# 0  https://knowyourmeme.com/memes/this-is-relevan...
# 1  https://knowyourmeme.com/memes/leave-britney-a...
# 2      https://knowyourmeme.com/memes/i-like-turtles
# 3   https://knowyourmeme.com/memes/bitches-dont-know
# 4               https://knowyourmeme.com/memes/o-rly

# %%
safeSearchToNumberCode = {
    "VERY_UNLIKELY": 0.0,
    "UNLIKELY": 0.25,
    "POSSIBLE": 0.5,
    "LIKELY": 0.75,
    "VERY_LIKELY": 1.0
}
def getSafeSearch(row):
  if (isinstance(row.safeSearchAnnotation, dict)):
    for key in row.safeSearchAnnotation.keys():
      row["safeSearch_"+key] = safeSearchToNumberCode[row.safeSearchAnnotation[key]]
  return row

# %%
df = df.apply(getSafeSearch, axis=1)
df = df.drop(columns=["safeSearchAnnotation"])

# %%
with open("kym_vision_processed.json", "w", encoding="utf-8") as f:
    f.write(df.to_json(orient='records', lines=True))

# %%
df2 = pd.read_json("kym_vision_processed.json", orient="records", lines=True)
df2.head()
# Out:
#   error                                   labelAnnotations  safeSearch_adult  \
# 0  None  [{'mid': '/m/01yrx', 'description': 'Cat', 'sc...              0.00
# 1  None  [{'mid': '/m/0dzct', 'description': 'Face', 's...              0.25
# 2  None  [{'mid': '/m/068jd', 'description': 'Photograp...              0.25
# 3  None  [{'mid': '/m/09j2d', 'description': 'Clothing'...              0.00
# 4  None  [{'mid': '/m/04hgtk', 'description': 'Head', '...              0.00
#
#    safeSearch_medical  safeSearch_racy  safeSearch_spoof  safeSearch_violence  \
# 0                0.00             0.00              1.00                 0.25
# 1                0.25             0.25              0.75                 0.25
# 2                0.25             0.00              1.00                 0.25
# 3                0.00             0.25              1.00                 0.25
# 4                0.25             0.00              1.00                 0.50
#
#                                                  url  \
# 0  https://knowyourmeme.com/memes/this-is-relevan...
# 1  https://knowyourmeme.com/memes/leave-britney-a...
# 2      https://knowyourmeme.com/memes/i-like-turtles
# 3   https://knowyourmeme.com/memes/bitches-dont-know
# 4               https://knowyourmeme.com/memes/o-rly
#
#                                         webDetection
# 0  {'webEntities': [{'entityId': '/m/04wpw', 'sco...
# 1  {'webEntities': [{'entityId': '/m/03bzkh4', 's...
# 2  {'webEntities': [{'entityId': '/m/09dzg', 'sco...
# 3  {'webEntities': [{'entityId': '/m/09kqc', 'sco...
# 4  {'webEntities': [{'entityId': '/m/06ng23', 'sc...

# %%
df2.to_parquet("kym_vision_processed.parquet")

# %%
df3 = pd.read_parquet('kym_vision_processed.parquet', engine='pyarrow')
df3.head()
# Out:
#   error                                   labelAnnotations  safeSearch_adult  \
# 0  None  [{'description': 'Cat', 'mid': '/m/01yrx', 'sc...              0.00
# 1  None  [{'description': 'Face', 'mid': '/m/0dzct', 's...              0.25
# 2  None  [{'description': 'Photograph', 'mid': '/m/068j...              0.25
# 3  None  [{'description': 'Clothing', 'mid': '/m/09j2d'...              0.00
# 4  None  [{'description': 'Head', 'mid': '/m/04hgtk', '...              0.00
#
#    safeSearch_medical  safeSearch_racy  safeSearch_spoof  safeSearch_violence  \
# 0                0.00             0.00              1.00                 0.25
# 1                0.25             0.25              0.75                 0.25
# 2                0.25             0.00              1.00                 0.25
# 3                0.00             0.25              1.00                 0.25
# 4                0.25             0.00              1.00                 0.50
#
#                                                  url  \
# 0  https://knowyourmeme.com/memes/this-is-relevan...
# 1  https://knowyourmeme.com/memes/leave-britney-a...
# 2      https://knowyourmeme.com/memes/i-like-turtles
# 3   https://knowyourmeme.com/memes/bitches-dont-know
# 4               https://knowyourmeme.com/memes/o-rly
#
#                                         webDetection
# 0  {'bestGuessLabels': [{'label': 'interest meme'...
# 1  {'bestGuessLabels': [{'label': 'leave britney ...
# 2  {'bestGuessLabels': [{'label': 'like turtles',...
# 3  {'bestGuessLabels': [{'label': 'eric harris fu...
# 4  {'bestGuessLabels': [{'label': 'o rly', 'langu...

# %%
def getLabelAnnotScores(row):
  if ((not type(row.labelAnnotations) == float) and len(row.labelAnnotations) > 0):
    newDict = {annot["description"]: annot["score"] for annot in row.labelAnnotations}
    for key in newDict.keys():
        row["annot_"+key] = newDict[key]
  return row

# %%
def getBestGuessLabel(row):
  if ((type(row.webDetection) == dict)):
    # and "bestGuessLabels" in row.webDetection and len(row.webDetection.bestGuessLabels) > 0):
    bestGuessLabels = row.webDetection.get("bestGuessLabels", [])
    if (len(bestGuessLabels) > 0 and 'label' in bestGuessLabels[0]):
      row["webDetection_bestGuessLabel"] = bestGuessLabels[0]['label']
  return row

# %%
df = df.apply(getLabelAnnotScores, axis=1)
df = df.drop(columns="labelAnnotations")

# %%
df = df.apply(getBestGuessLabel, axis=1)
df = df.drop(columns="webDetection")

# %%
df.head()
# Out:
#    annot_3d modeling  ...  webDetection_bestGuessLabel
# 0                NaN  ...                interest meme
# 1                NaN  ...          leave britney alone
# 2                NaN  ...                 like turtles
# 3                NaN  ...            eric harris funny
# 4                NaN  ...                        o rly
#
# [5 rows x 4730 columns]

# %%
df.to_parquet("/content/drive/My Drive/dataEngProject/kym_vision_processed.parquet")

# %%
len(df.columns)
# Out:
# 4730

# %%
df.shape
# Out:
# (16686, 4730)
